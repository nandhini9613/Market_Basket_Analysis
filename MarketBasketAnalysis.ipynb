# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
groceries=pd.read_csv('/content/drive/MyDrive/grocery.csv')
groceries
# Out:
#        memberNumber        Date        itemDescription
# 0              1808  21-07-2015         tropical fruit
# 1              1808  21-07-2015                  candy
# 2              2300  19-09-2015              pip fruit
# 3              1187  12-12-2015       other vegetables
# 4              3037  01-02-2015             whole milk
# ...             ...         ...                    ...
# 38760          4471  08-10-2014          sliced cheese
# 38761          2022  23-02-2014                  candy
# 38762          1097  16-04-2014               cake bar
# 38763          1510  03-12-2014  fruit/vegetable juice
# 38764          1521  26-12-2014               cat food
#
# [38765 rows x 3 columns]

# %%
groceries.head()
# Out:
#    memberNumber        Date   itemDescription
# 0          1808  21-07-2015    tropical fruit
# 1          1808  21-07-2015             candy
# 2          2300  19-09-2015         pip fruit
# 3          1187  12-12-2015  other vegetables
# 4          3037  01-02-2015        whole milk

# %%
groceries.tail()
# Out:
#        memberNumber        Date        itemDescription
# 38760          4471  08-10-2014          sliced cheese
# 38761          2022  23-02-2014                  candy
# 38762          1097  16-04-2014               cake bar
# 38763          1510  03-12-2014  fruit/vegetable juice
# 38764          1521  26-12-2014               cat food

# %%
groceries.shape
# Out:
# (38765, 3)

# %%
groceries.size
# Out:
# 116295

# %%
groceries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38765 entries, 0 to 38764
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   memberNumber     38765 non-null  int64
#  1   Date             38765 non-null  object
#  2   itemDescription  38765 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 908.7+ KB

# %%
groceries.describe()
# Out:
#        memberNumber
# count  38765.000000
# mean    3003.641868
# std     1153.611031
# min     1000.000000
# 25%     2002.000000
# 50%     3005.000000
# 75%     4007.000000
# max     5000.000000

# %%
groceries.ndim
# Out:
# 2

# %%
groceries.isnull()
# Out:
#        memberNumber   Date  itemDescription
# 0             False  False            False
# 1             False  False            False
# 2             False  False            False
# 3             False  False            False
# 4             False  False            False
# ...             ...    ...              ...
# 38760         False  False            False
# 38761         False  False            False
# 38762         False  False            False
# 38763         False  False            False
# 38764         False  False            False
#
# [38765 rows x 3 columns]

# %%
groceries.isnull().sum()
# Out:
# memberNumber       0
# Date               0
# itemDescription    0
# dtype: int64

# %%
groceries.isna().sum()
# Out:
# memberNumber       0
# Date               0
# itemDescription    0
# dtype: int64

# %%
groceries.dropna()
# Out:
#        memberNumber        Date        itemDescription
# 0              1808  21-07-2015         tropical fruit
# 1              1808  21-07-2015                  candy
# 2              2300  19-09-2015              pip fruit
# 3              1187  12-12-2015       other vegetables
# 4              3037  01-02-2015             whole milk
# ...             ...         ...                    ...
# 38760          4471  08-10-2014          sliced cheese
# 38761          2022  23-02-2014                  candy
# 38762          1097  16-04-2014               cake bar
# 38763          1510  03-12-2014  fruit/vegetable juice
# 38764          1521  26-12-2014               cat food
#
# [38765 rows x 3 columns]

# %%
groceries.columns
# Out:
# Index(['memberNumber', 'Date', 'itemDescription'], dtype='object')

# %%
groceries.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 38760    False
# 38761    False
# 38762    False
# 38763    False
# 38764    False
# Length: 38765, dtype: bool

# %%
groceries.drop_duplicates()
# Out:
#        memberNumber        Date        itemDescription
# 0              1808  21-07-2015         tropical fruit
# 1              1808  21-07-2015                  candy
# 2              2300  19-09-2015              pip fruit
# 3              1187  12-12-2015       other vegetables
# 4              3037  01-02-2015             whole milk
# ...             ...         ...                    ...
# 38760          4471  08-10-2014          sliced cheese
# 38761          2022  23-02-2014                  candy
# 38762          1097  16-04-2014               cake bar
# 38763          1510  03-12-2014  fruit/vegetable juice
# 38764          1521  26-12-2014               cat food
#
# [38005 rows x 3 columns]

# %%
# Convert 'Date' column to datetime objects
groceries['Date'] = pd.to_datetime(groceries['Date'], format='%d-%m-%Y')

# %%
groceries.head()
# Out:
#    memberNumber       Date   itemDescription
# 0          1808 2015-07-21    tropical fruit
# 1          1808 2015-07-21             candy
# 2          2300 2015-09-19         pip fruit
# 3          1187 2015-12-12  other vegetables
# 4          3037 2015-02-01        whole milk

# %%
# Most Frequent Items (Bar)

top_items = groceries['itemDescription'].value_counts().head(10).reset_index()
top_items.columns = ['Item', 'Count']
fig1 = px.bar(top_items, x='Item', y='Count', title='Top 10 Most Purchased Items')
fig1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Purchase Trend Over Time

daily_counts = groceries.groupby('Date').size().reset_index(name='Purchases')

fig2 = px.line(daily_counts, x='Date', y='Purchases', title='Purchase Trend Over Time')
fig2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Treemap of Items
fig4 = px.treemap(top_items, path=['Item'], values='Count', title='Item Popularity Treemap')
fig4.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Unique Items Per Member (Bar)
unique_items = groceries.groupby('memberNumber')['itemDescription'].nunique().reset_index()
unique_items.columns = ['memberNumber', 'Unique_Items']

top_members = unique_items.sort_values('Unique_Items', ascending=False).head(10)

fig5 = px.bar(top_members, x='memberNumber', y='Unique_Items',
              title='Top 10 Members by Unique Items Bought')
fig5.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
groceries.to_csv('cleaned_grocery.csv', index=False)

# %%
from google.colab import files
files.download('cleaned_grocery.csv')
